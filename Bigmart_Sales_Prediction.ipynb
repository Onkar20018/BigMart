# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
dt = pd.read_csv('Big_mart_sales.csv')
dt.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
dt.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
dt.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
# ## Preprocessing the dataset

# %%
dt.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
cat_col = []
for x in dt.dtypes.index:
    if dt.dtypes[x] == 'object':
        cat_col.append(x)
cat_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
cat_col
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for col in cat_col:
    print(col)
    print(dt[col].value_counts())
    print()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
item_weight_mean = dt.pivot_table(values = "Item_Weight", index = 'Item_Identifier')
item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
miss_bool = dt['Item_Weight'].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
for i, item in enumerate(dt['Item_Identifier']):
    if miss_bool[i]:
        if item in item_weight_mean:
            dt['Item_Weight'][i] = item_weight_mean.loc[item]['Item_Weight']
        else:
            dt['Item_Weight'][i] = np.mean(dt['Item_Weight'])
# Out:
# C:\Users\onkar\AppData\Local\Temp\ipykernel_13060\4113020904.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['Item_Weight'][i] = np.mean(dt['Item_Weight'])

# %%
dt['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
outlet_size_mode = dt.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
miss_bool = dt['Outlet_Size'].isnull()
dt.loc[miss_bool, 'Outlet_Size'] = dt.loc[miss_bool, 'Outlet_Type'].apply(lambda x: outlet_size_mode[x])

# %%
dt['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
sum(dt['Item_Visibility']==0)
# Out:
# 526

# %%
# replace zeros with mean
dt.loc[:, 'Item_Visibility'].replace([0], [dt['Item_Visibility'].mean()], inplace=True)

# %%
sum(dt['Item_Visibility']==0)
# Out:
# 0

# %%
# combine item fat content
dt['Item_Fat_Content'] = dt['Item_Fat_Content'].replace({'LF':'Low Fat', 'reg':'Regular', 'low fat':'Low Fat'})
dt['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# ## Creating New Attributes

# %%
dt['New_Item_Type'] = dt['Item_Identifier'].apply(lambda x: x[:2])
dt['New_Item_Type']
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
dt['New_Item_Type'] = dt['New_Item_Type'].map({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
dt['New_Item_Type'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: New_Item_Type, dtype: int64

# %%
dt.loc[dt['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
dt['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
dt.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type
# 0  Supermarket Type1          3735.1380            Food
# 1  Supermarket Type2           443.4228          Drinks
# 2  Supermarket Type1          2097.2700            Food
# 3      Grocery Store           732.3800            Food
# 4  Supermarket Type1           994.7052  Non-Consumable

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.distplot(dt['Item_Weight'])
# Out:
# C:\Users\onkar\AppData\Local\Temp\ipykernel_13060\4044040405.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['Item_Weight'])
# <AxesSubplot: xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(dt['Item_Visibility'])
# Out:
# C:\Users\onkar\AppData\Local\Temp\ipykernel_13060\1582113114.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['Item_Visibility'])
# <AxesSubplot: xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(dt['Item_MRP'])
# Out:
# C:\Users\onkar\AppData\Local\Temp\ipykernel_13060\3538340660.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['Item_MRP'])
# <AxesSubplot: xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(dt['Item_Outlet_Sales'])
# Out:
# C:\Users\onkar\AppData\Local\Temp\ipykernel_13060\1110053806.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['Item_Outlet_Sales'])
# <AxesSubplot: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
# log transformation
dt['Item_Outlet_Sales'] = np.log(1+dt['Item_Outlet_Sales'])

# %%
sns.distplot(dt['Item_Outlet_Sales'])
# Out:
# C:\Users\onkar\AppData\Local\Temp\ipykernel_13060\1110053806.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['Item_Outlet_Sales'])
# <AxesSubplot: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.countplot(dt["Item_Fat_Content"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 sns.countplot(dt["Item_Fat_Content"])
#
# File c:\Users\onkar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:2939, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2936 elif x is not None and y is not None:
#    2937     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2939 plotter = _CountPlotter(
#    2940     x, y, hue, data, order, hue_order,
#    2941     estimator, errorbar, n_boot, units, seed,
#    2942     orient, color, palette, saturation,
#    2943     width, errcolor, errwidth, capsize, dodge
#    2944 )
#    2946 plotter.value_label = "count"
#    2948 if ax is None:
#
# File c:\Users\onkar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File c:\Users\onkar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:516, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     513     plot_data = data
#     515 # Convert to a list of arrays, the common representation
# --> 516 plot_data = [np.asarray(d, float) for d in plot_data]
#     518 # The group names will just be numeric indices
#     519 group_names = list(range(len(plot_data)))
#
# File c:\Users\onkar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:516, in <listcomp>(.0)
#     513     plot_data = data
#     515 # Convert to a list of arrays, the common representation
# --> 516 plot_data = [np.asarray(d, float) for d in plot_data]
#     518 # The group names will just be numeric indices
#     519 group_names = list(range(len(plot_data)))
#
# File c:\Users\onkar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:872, in Series.__array__(self, dtype)
#     825 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     826     """
#     827     Return the values as a NumPy array.
#     828
#    (...)
#     870           dtype='datetime64[ns]')
#     871     """
# --> 872     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: 'Low Fat'

# %%
# plt.figure(figsize=(15,5))
l = list(dt['Item_Type'].unique())
chart = sns.countplot(dt["Item_Type"])
chart.set_xticklabels(labels=l, rotation=90)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0, 'Dairy'),
#  Text(0, 0, 'Soft Drinks'),
#  Text(0, 0, 'Meat'),
#  Text(0, 0, 'Fruits and Vegetables'),
#  Text(0, 0, 'Household'),
#  Text(0, 0, 'Baking Goods'),
#  Text(0, 0, 'Snack Foods'),
#  Text(0, 0, 'Frozen Foods'),
#  Text(0, 0, 'Breakfast'),
#  Text(0, 0, 'Health and Hygiene'),
#  Text(0, 0, 'Hard Drinks'),
#  Text(0, 0, 'Canned'),
#  Text(0, 0, 'Breads'),
#  Text(0, 0, 'Starchy Foods'),
#  Text(0, 0, 'Others'),
#  Text(0, 0, 'Seafood')]

# %%
sns.countplot(dt['Outlet_Establishment_Year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(dt['Outlet_Size'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(dt['Outlet_Location_Type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(dt['Outlet_Type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Coorelation Matrix

# %%
corr = dt.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')

# %%
dt.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type
# 0  Supermarket Type1           8.225808            Food
# 1  Supermarket Type2           6.096776          Drinks
# 2  Supermarket Type1           7.648868            Food
# 3      Grocery Store           6.597664            Food
# 4  Supermarket Type1           6.903451  Non-Consumable

# %%
print(dt.head(n=1).to_string(index=False))
# Out:
# Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type       Outlet_Type  Item_Outlet_Sales New_Item_Type
#           FDA15          9.3          Low Fat         0.016047     Dairy  249.8092            OUT049                       1999      Medium               Tier 1 Supermarket Type1           8.225808          Food

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# dt['Outlet'] = le.fit_transform(dt['Outlet_Identifier'])
cat_col = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type']
for col in cat_col:
    dt[col] = le.fit_transform(dt[col])

# %%
dt.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 0         0.016760         10
# 3           FDX07        19.20                 2         0.066132          6
# 4           NCD19         8.93                 1         0.066132          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            2
# 4   53.8614            OUT013                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type
# 0                     0            1           8.225808              1
# 1                     2            2           6.096776              0
# 2                     0            1           7.648868              1
# 3                     2            0           6.597664              1
# 4                     2            1           6.903451              2

# %% [markdown]
# ## One hot Encoding

# %%
dt.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 0         0.016760         10
# 3           FDX07        19.20                 2         0.066132          6
# 4           NCD19         8.93                 1         0.066132          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            2
# 4   53.8614            OUT013                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type
# 0                     0            1           8.225808              1
# 1                     2            2           6.096776              0
# 2                     0            1           7.648868              1
# 3                     2            0           6.597664              1
# 4                     2            1           6.903451              2

# %%
print(dt.head(n=1).to_string(index=False))
# Out:
# Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type
#           FDA15          9.3                 0         0.016047          4  249.8092            OUT049                       1999            1                     0            1           8.225808              1

# %% [markdown]
# ## Input Split

# %%
X = dt.drop(columns=[ 'Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales', 'Outlet_Establishment_Year'], axis=1)
y = dt['Item_Outlet_Sales']

# %%
X_copy= X
X_copy
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 0         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 0         0.016760         10  141.6180
# 3          19.200                 2         0.066132          6  182.0950
# 4           8.930                 1         0.066132          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 0         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 0         0.044878         14   75.4670
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  New_Item_Type
# 0               1                     0            1              1
# 1               1                     2            2              0
# 2               1                     0            1              1
# 3               2                     2            0              1
# 4               0                     2            1              2
# ...           ...                   ...          ...            ...
# 8518            0                     2            1              1
# 8519            2                     1            1              1
# 8520            2                     1            1              2
# 8521            1                     2            2              1
# 8522            2                     0            1              0
#
# [8523 rows x 9 columns]

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


linear = LinearRegression()
linear.fit(X_train, y_train)

# predicting the  test set results
Y_pred = linear.predict(X_test)
print(Y_pred)

# finding the mean squared error and variance
mse = mean_squared_error(y_test, Y_pred)
print('RMSE :', np.sqrt(mse))
print(r2_score(y_test, Y_pred))
print('Variance score: %.2f' % r2_score(y_test, Y_pred))
linear_accuracy=round(linear.score(X_train, y_train)*100, 2)
print('accuracy: %.4g' %linear_accuracy)
# Out:
# [7.22331817 7.80146527 7.13461065 ... 7.42859883 7.22018639 7.23159032]
# RMSE : 0.7008689775966026
# 0.5341269447022707
# Variance score: 0.53
# accuracy: 54.56

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 100 , n_jobs = -1)
model.fit(X_train, y_train)

# predicting the  test set results
Y_pred = model.predict(X_test)
print(Y_pred)

# finding the mean squared error and variance
mse = mean_squared_error(y_test, Y_pred)
print("RMSE :",np.sqrt(mse))
print('Variance score: %.2f' % r2_score(y_test, Y_pred))
print(r2_score(y_test, Y_pred))
# Out:
# [7.79180296 7.39402435 7.85215295 ... 7.21402817 7.52766875 7.98614376]
# RMSE : 0.5746652714647174
# Variance score: 0.69
# 0.6867985074860954

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor()
model.fit(X_train, y_train)

# predicting the test set results
Y_pred = model.predict(X_test)
print(y_test)
print(np.array([[y_test, Y_pred]]))
print(r2_score(y_test, Y_pred))
# Calculating the root mean squared error
print("RMSE :", np.sqrt(((y_test - Y_pred)**2).sum()/len(y_test)))
model_accuracy=round(model.score(X_train, y_train)*100, 2)
print('accuracy: %.4g' %model_accuracy)
# Out:
# 4931    7.263430
# 4148    7.092382
# 7423    7.516040
# 4836    7.788154
# 944     7.346644
#           ...
# 5460    8.005400
# 7384    7.684403
# 1336    7.592074
# 8455    8.344630
# 5516    8.083159
# Name: Item_Outlet_Sales, Length: 2557, dtype: float64
# [[[7.26343024 7.09238168 7.51603954 ... 7.592074   8.34462973 8.08315921]
#   [7.75091373 7.43877374 7.5717889  ... 7.33909573 7.73325311 7.89829303]]]
# 0.728610111638881
# RMSE : 0.5349335933746299
# accuracy: 76.27

# %%
from xgboost import XGBRegressor
regressor = XGBRegressor()
regressor.fit(X_train, y_train)
TS=regressor.score(X_train, y_train)
print(TS)
print(r2_score(y_test, Y_pred))
print(np.exp(y_test), np.exp(Y_pred))
regressor_accuracy=round(regressor.score(X_train, y_train)*100, 2)
print('accuracy: %.4g' %regressor_accuracy)
# Out:
# [05:49:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.7611269065902033
# 0.728610111638881
# 4931    1427.1436
# 4148    1202.7690
# 7423    1837.2764
# 4836    2411.8618
# 944     1550.9824
#           ...
# 5460    2997.1000
# 7384    2174.1712
# 1336    1982.4208
# 8455    4207.5244
# 5516    3239.4512
# Name: Item_Outlet_Sales, Length: 2557, dtype: float64 [2323.69467247 1700.66347809 1942.61231442 ... 1539.31952877 2283.01704028
#  2692.68208379]
# accuracy: 76.11

# %%
data = {'Linear Regression': linear_accuracy,
        'Random Forest Regression': regressor_accuracy ,
        'Gradient Boosting Regression': model_accuracy}
courses = list(data.keys())
values = list(data.values())

fig= plt.figure(figsize =(10, 5))

plt.bar(courses, values, color='blue', width=0.3)

plt.xlabel('Algorithms')
plt.ylabel("Accuracy(%)")
plt.show()
